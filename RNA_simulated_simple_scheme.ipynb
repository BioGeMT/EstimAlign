# %%
# %matplotlib inline
# changed from %matplotlib notebook as graphs werent being plotted

# %%
from Bio.Align import PairwiseAligner, substitution_matrices
from Bio.Seq import Seq 
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
import numpy as np
from numpy import random as rd
from matplotlib import pyplot as plt

import os
import pickle
from matplotlib.ticker import MaxNLocator, ScalarFormatter, FormatStrFormatter
from matplotlib.ticker import LinearLocator
FIGSIZE = (4.5,3)
DPI = 300
N_TICKS = 3

# %%
from src.discrimalign import discrimalign
from src.logit_link import logit_partial_scores
from src.optimization import create_powerstep, create_constant_step

# %% [markdown]
# # Data

# %%
from miRBench.dataset import list_datasets, get_dataset_df

# %%
hejret_train = get_dataset_df(list_datasets()[0], split="train")
hejret_test = get_dataset_df(list_datasets()[0], split="test")
# Out:
# Using cached dataset /home/dave/.miRBench/datasets/14501607/AGO2_CLASH_Hejret2023/train/dataset.tsv
# Using cached dataset /home/dave/.miRBench/datasets/14501607/AGO2_CLASH_Hejret2023/test/dataset.tsv

# %%
mirlist = hejret_train['noncodingRNA']
mirlist = [Seq(seq) for seq in mirlist]
genelist = hejret_train['gene']
genelist = [Seq(seq).reverse_complement() for seq in genelist]

# %% [markdown]
# # Optimization

# %% [markdown]
# ### Simple model on miRNA alignments:

# %%
true_match = 1
true_mismatch = -1
true_gapopen = -1.2
true_gapext = -0.1

# %%
aligner = PairwiseAligner()
aligner.mode = 'local'
aligner.open_gap_score = true_gapopen
aligner.extend_gap_score = true_gapext
aligner.match = true_match
aligner.mismatch = true_mismatch
# aligner.end_gap_score = 0

# %%
scores = np.array([aligner.score(a, b) for a, b in zip(mirlist, genelist)])

# %%
plt.figure()
plt.hist(scores, bins=100)
plt.show()

# %%
true_alpha = -9
## true_alpha = -np.median(scores)

# %%
logit_scores = logit_partial_scores(scores, true_alpha)

# %%
plt.figure()
plt.hist(logit_scores, bins=100)
plt.show()

# %% [markdown]
# ### Test Run

# %%
labels = rd.rand(len(mirlist))
labels = labels <= logit_scores
labels
# Out:
# array([False,  True, False, ..., False, False,  True], shape=(8193,))

# %%
true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
print('Sum of log-logit scores:', np.sum(np.log(logit_scores)))
print('True LogL:', true_logL) ## This is different
# Out:
# Sum of log-logit scores: -10002.78024009512
# True LogL: -3243.180240095122

# %%
plt.figure()
plt.plot(scores, labels, 'r.', alpha=0.005)

# %%
plt.figure()
plt.plot(logit_scores, labels, 'r.', alpha=0.005)

# %%
const_step = create_constant_step(0.00001)
# powerstep = create_powerstep(0.00001, power=0.5, burnin=0)
# powerstep = create_powerstep(0.00001, power=-0.5, burnin=0)

# %%
NITER = 50# original 50

# %%
params = discrimalign(mirlist, genelist, labels, 
                    stepfunction=const_step,
                    aligner_mode='local',
                    substitution_mode='simple',
                    verbose=True, max_iter=NITER,
                    stochastic_factor=None,
                    num_threads = 16)
# Out:
# Alphabet:
# ACGT
# /home/dave/Documents/Bioinformatics/estimalign/env/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Initial parameters:
# {'alpha': np.float64(-8.315897138480349), 'match_score': np.float64(0.9540292205373561), 'mismatch_score': np.float64(-0.8418014161486086), 'open_gap_score': np.float64(-1.2030259089440918), 'extend_gap_score': np.float64(-0.10529329489706982)}
# Start of iteration 0
# Current alpha: -8.315897138480349
# Current logL: -3288.5845386321416
# Updated alpha: -8.480444625344715
# Updated logL: -3273.736152109189
# New subgradient:
# {'Substitutions': Array([[ -0.22079991,  -4.12823498, -19.42291095, -14.28985418],
#        [-25.28758285,  24.63773783, -25.62423636,  -4.72108261],
#        [-34.85813627,   0.74188338,  55.24307496,  -3.04851832],
#        [-10.74461986, -28.90146823, -37.62827749, 202.73842053]],
#          alphabet='ACGT'), 'Gap opens': np.float64(245.82416525603136), 'Gap extends': np.float64(330.8232959300725)}
# Stepsize: 1e-05
# Gap open step: 0.002458241652560314
# Gap extend step: 0.003308232959300725
# Match step: 0.0028239843340845893
# Mismatch step: -0.0020791303871107807
# New parameters:
# {'alpha': np.float64(-8.480444625344715), 'match_score': np.float64(0.9568532048714407), 'mismatch_score': np.float64(-0.8438805465357194), 'open_gap_score': np.float64(-1.2005676672915315), 'extend_gap_score': np.float64(-0.10198506193776909)}
# Subgradient norm: 541.1564285966554
# End of iteration 0
#
# Start of iteration 1
# Current alpha: -8.480444625344715
# Current logL: -3273.730265102836
# Updated alpha: -8.551907082280817
# Updated logL: -3270.9372821397537
# New subgradient:
# {'Substitutions': Array([[ -8.94511771,  -3.26457551, -18.05410414, -13.35068377],
#        [-24.84235217,  17.99451499, -24.72926661,  -3.12528434],
#        [-32.74266271,  -0.44126384,  46.19318264,  -1.04273687],
#        [-11.34566723, -32.56596584, -36.09092812, 200.05623397]],
#          alphabet='ACGT'), 'Gap opens': np.float64(228.4470808074311), 'Gap extends': np.float64(263.87388989100265)}
# Stepsize: 1e-05
# Gap open step: 0.0022844708080743113
# Gap extend step: 0.0026387388989100266
# Match step: 0.0025529881388631033
# Mismatch step: -0.002015954911605783
# New parameters:
# {'alpha': np.float64(-8.551907082280817), 'match_score': np.float64(0.9594061930103037), 'mismatch_score': np.float64(-0.8458965014473252), 'open_gap_score': np.float64(-1.1982831964834573), 'extend_gap_score': np.float64(-0.09934632303885906)}
# Subgradient norm: 477.11185787368316
# End of iteration 1
#
# Start of iteration 2
# Current alpha: -8.551907082280817
# Current logL: -3270.8735950207424
# Updated alpha: -8.614831363719068
# Updated logL: -3268.7107495292785
# New subgradient:
# {'Substitutions': Array([[-11.2457023 ,  -2.53724116, -18.90231256, -15.09335893],
#        [-24.82941089,  14.62048828, -26.00023645,  -0.30651855],
#        [-33.40001543,   0.21226347,  40.89389368,  -2.49790652],
#        [-12.3297995 , -31.48885741, -33.29990501, 191.35781468]],
#          alphabet='ACGT'), 'Gap opens': np.float64(219.73346575646684), 'Gap extends': np.float64(203.57159091483027)}
# Stepsize: 1e-05
# Gap open step: 0.0021973346575646685
# Gap extend step: 0.0020357159091483027
# Match step: 0.002356264943467773
# Mismatch step: -0.0020047329894876897
# New parameters:
# {'alpha': np.float64(-8.614831363719068), 'match_score': np.float64(0.9617624579537715), 'mismatch_score': np.float64(-0.8479012344368129), 'open_gap_score': np.float64(-1.1960858618258925), 'extend_gap_score': np.float64(-0.09731060712971075)}
# Subgradient norm: 430.619991443149
# End of iteration 2
#
# Start of iteration 3
# Current alpha: -8.614831363719068
# Current logL: -3268.6697328962014
# Updated alpha: -8.670416641386891
# Updated logL: -3266.9839505038217
# New subgradient:
# {'Substitutions': Array([[-18.84891187,  -3.07366069, -18.4568724 , -13.92592454],
#        [-27.87355337,   1.06216532, -26.54785035,   0.58976974],
#        [-33.61007383,  -0.49148029,  37.49747677,  -3.35445712],
#        [-13.79847181, -31.94098899, -32.1781358 , 177.56250123]],
#          alphabet='ACGT'), 'Gap opens': np.float64(202.57469543171192), 'Gap extends': np.float64(106.81756406370373)}
# Stepsize: 1e-05
# Gap open step: 0.0020257469543171194
# Gap extend step: 0.0010681756406370373
# Match step: 0.0019727323145044247
# Mismatch step: -0.002046616994344426
# New parameters:
# {'alpha': np.float64(-8.670416641386891), 'match_score': np.float64(0.9637351902682759), 'mismatch_score': np.float64(-0.8499478514311573), 'open_gap_score': np.float64(-1.1940601148715755), 'extend_gap_score': np.float64(-0.09624243148907372)}
# Subgradient norm: 365.03374951372405
# End of iteration 3
#
# Start of iteration 4
# Current alpha: -8.670416641386891
# Current logL: -3266.637089603857
# Updated alpha: -8.712377315707068
# Updated logL: -3265.6776380597566
# New subgradient:
# {'Substitutions': Array([[-23.38717005,  -3.38009127, -18.74811307, -15.09370766],
#        [-26.55215879,  -3.43199917, -26.8556147 ,   2.10133655],
#        [-31.9910757 ,  -1.30823484,  37.18264894,  -3.86116122],
#        [-12.28192221, -31.51981259, -30.48245575, 172.05113039]],
#          alphabet='ACGT'), 'Gap opens': np.float64(191.71785438062903), 'Gap extends': np.float64(84.15428387945984)}
# Stepsize: 1e-05
# Gap open step: 0.0019171785438062904
# Gap extend step: 0.0008415428387945985
# Match step: 0.001824146101110786
# Mismatch step: -0.001999730112394277
# New parameters:
# {'alpha': np.float64(-8.712377315707068), 'match_score': np.float64(0.9655593363693867), 'mismatch_score': np.float64(-0.8519475815435515), 'open_gap_score': np.float64(-1.1921429363277691), 'extend_gap_score': np.float64(-0.09540088865027911)}
# Subgradient norm: 342.20165749119025
# End of iteration 4
#
# Start of iteration 5
# Current alpha: -8.712377315707068
# Current logL: -3265.3064826118925
# Updated alpha: -8.750156455572727
# Updated logL: -3264.5295339280037
# New subgradient:
# {'Substitutions': Array([[-29.96743675,  -1.50781175, -18.64477621, -14.70279565],
#        [-26.74386194,   0.25685272, -26.50975004,   2.77182794],
#        [-31.44023638,   1.21106996,  33.74395891,  -4.05636335],
#        [-10.95619735, -31.07916022, -29.98712246, 172.15034189]],
#          alphabet='ACGT'), 'Gap opens': np.float64(186.5230809354999), 'Gap extends': np.float64(43.28344835208857)}
# Stepsize: 1e-05
# Gap open step: 0.0018652308093549993
# Gap extend step: 0.0004328344835208857
# Match step: 0.0017618371675950921
# Mismatch step: -0.0019164517744195042
# New parameters:
# {'alpha': np.float64(-8.750156455572727), 'match_score': np.float64(0.9673211735369818), 'mismatch_score': np.float64(-0.853864033317971), 'open_gap_score': np.float64(-1.1902777055184142), 'extend_gap_score': np.float64(-0.09496805416675823)}
# Subgradient norm: 323.16078461173254
# End of iteration 5
#
# Start of iteration 6
# Current alpha: -8.750156455572727
# Current logL: -3264.096432624365
# Updated alpha: -8.783825684550122
# Updated logL: -3263.479998474999
# New subgradient:
# {'Substitutions': Array([[-27.87271506,  -1.67722107, -18.04825161, -14.38403215],
#        [-26.51176785,  -3.85281935, -24.45851104,   1.66236075],
#        [-31.5546164 ,   1.34861311,  33.39286854,  -3.03401499],
#        [ -9.43434432, -31.74543119, -31.38374058, 171.90697125]],
#          alphabet='ACGT'), 'Gap opens': np.float64(188.12213121085338), 'Gap extends': np.float64(7.539627930826755)}
# Stepsize: 1e-05
# Gap open step: 0.0018812213121085339
# Gap extend step: 7.539627930826755e-05
# Match step: 0.001735743053868789
# Mismatch step: -0.0018922095732926256
# New parameters:
# {'alpha': np.float64(-8.783825684550122), 'match_score': np.float64(0.9690569165908506), 'mismatch_score': np.float64(-0.8557562428912636), 'open_gap_score': np.float64(-1.1883964842063057), 'extend_gap_score': np.float64(-0.09489265788744997)}
# Subgradient norm: 318.40130719547767
# End of iteration 6
#
# Start of iteration 7
# Current alpha: -8.783825684550122
# Current logL: -3262.9933408998877
# Updated alpha: -8.814421730199552
# Updated logL: -3262.484871151377
# New subgradient:
# {'Substitutions': Array([[-30.3176134 ,  -3.10240652, -17.10138183, -14.60056009],
#        [-26.62770131,  -5.80821042, -26.40658754,   3.11199041],
#        [-31.49305934,   0.7502419 ,  28.57416117,  -3.01960794],
#        [ -8.46344147, -31.44914817, -32.13920697, 165.42656912]],
#          alphabet='ACGT'), 'Gap opens': np.float64(178.041733651119), 'Gap extends': np.float64(20.09225278174205)}
# Stepsize: 1e-05
# Gap open step: 0.00178041733651119
# Gap extend step: 0.00020092252781742052
# Match step: 0.001578749064704639
# Mismatch step: -0.0019054086887954637
# New parameters:
# {'alpha': np.float64(-8.814421730199552), 'match_score': np.float64(0.9706356656555553), 'mismatch_score': np.float64(-0.8576616515800591), 'open_gap_score': np.float64(-1.1866160668697945), 'extend_gap_score': np.float64(-0.09469173535963255)}
# Subgradient norm: 305.50428204817626
# End of iteration 7
#
# Start of iteration 8
# Current alpha: -8.814421730199552
# Current logL: -3262.0178645877477
# Updated alpha: -8.843289315177362
# Updated logL: -3261.5656630544345
# New subgradient:
# {'Substitutions': Array([[-34.34551082,  -2.92723702, -17.50502774, -13.43738352],
#        [-27.1735908 ,  -6.51906122, -26.00794411,   2.69470868],
#        [-30.07174607,   1.59768291,  30.34668989,  -2.07136173],
#        [ -8.92603909, -29.20188914, -33.60906854, 162.00863338]],
#          alphabet='ACGT'), 'Gap opens': np.float64(176.053783414387), 'Gap extends': np.float64(-24.880032144492795)}
# Stepsize: 1e-05
# Gap open step: 0.00176053783414387
# Gap extend step: -0.00024880032144492794
# Match step: 0.0015149075123347118
# Mismatch step: -0.001866388961764858
# New parameters:
# {'alpha': np.float64(-8.843289315177362), 'match_score': np.float64(0.97215057316789), 'mismatch_score': np.float64(-0.859528040541824), 'open_gap_score': np.float64(-1.1848555290356506), 'extend_gap_score': np.float64(-0.09494053568107748)}
# Subgradient norm: 298.9941068470905
# End of iteration 8
#
# Start of iteration 9
# Current alpha: -8.843289315177362
# Current logL: -3261.00614008664
# Updated alpha: -8.867620543405344
# Updated logL: -3260.6852419636025
# New subgradient:
# {'Substitutions': Array([[-37.04956288,  -2.73748255, -16.88332627, -13.34144192],
#        [-27.23620813,  -9.88318259, -25.76477996,   2.8813476 ],
#        [-29.68211537,   1.78925393,  31.23799123,  -2.09190056],
#        [ -8.79878208, -29.45186484, -30.42354255, 159.80189284]],
#          alphabet='ACGT'), 'Gap opens': np.float64(169.57315615240827), 'Gap extends': np.float64(-31.40840265914317)}
# Stepsize: 1e-05
# Gap open step: 0.001695731561524083
# Gap extend step: -0.00031408402659143176
# Match step: 0.001441071386056541
# Mismatch step: -0.0018174084269873482
# New parameters:
# {'alpha': np.float64(-8.867620543405344), 'match_score': np.float64(0.9735916445539465), 'mismatch_score': np.float64(-0.8613454489688113), 'open_gap_score': np.float64(-1.1831597974741266), 'extend_gap_score': np.float64(-0.09525461970766891)}
# Subgradient norm: 289.02965997807803
# End of iteration 9
#
# Start of iteration 10
# Current alpha: -8.867620543405344
# Current logL: -3260.149169803652
# Updated alpha: -8.890194490164506
# Updated logL: -3259.8732270656456
# New subgradient:
# {'Substitutions': Array([[-47.32627384,  -1.60911042, -16.02769783, -13.61820777],
#        [-27.13470546, -12.69126138, -25.67732923,   3.16466413],
#        [-28.77411813,   2.94133851,  26.85058439,  -1.1972732 ],
#        [ -9.82241554, -28.48333649, -30.94927451, 162.67653149]],
#          alphabet='ACGT'), 'Gap opens': np.float64(158.17026520306592), 'Gap extends': np.float64(-48.74660547552625)}
# Stepsize: 1e-05
# Gap open step: 0.0015817026520306594
# Gap extend step: -0.00048746605475526254
# Match step: 0.0012950958065998442
# Mismatch step: -0.001771874659464657
# New parameters:
# {'alpha': np.float64(-8.890194490164506), 'match_score': np.float64(0.9748867403605463), 'mismatch_score': np.float64(-0.863117323628276), 'open_gap_score': np.float64(-1.181578094822096), 'extend_gap_score': np.float64(-0.09574208576242417)}
# Subgradient norm: 274.8857833920295
# End of iteration 10
#
# Start of iteration 11
# Current alpha: -8.890194490164506
# Current logL: -3259.324003986644
# Updated alpha: -8.908832472247088
# Updated logL: -3259.1360848785002
# New subgradient:
# {'Substitutions': Array([[-52.62843277,  -0.37893549, -15.60846614, -13.95944702],
#        [-28.26677394, -14.04195414, -25.51086201,   2.685128  ],
#        [-27.71447092,   3.18452469,  19.67468623,  -1.44045222],
#        [-10.79476707, -28.298172  , -29.91465494, 159.92176217]],
#          alphabet='ACGT'), 'Gap opens': np.float64(146.09114399317198), 'Gap extends': np.float64(-49.599412454894654)}
# Stepsize: 1e-05
# Gap open step: 0.00146091143993172
# Gap extend step: -0.0004959941245489466
# Match step: 0.0011292606148862957
# Mismatch step: -0.0017601734904990334
# New parameters:
# {'alpha': np.float64(-8.908832472247088), 'match_score': np.float64(0.9760160009754326), 'mismatch_score': np.float64(-0.864877497118775), 'open_gap_score': np.float64(-1.1801171833821642), 'extend_gap_score': np.float64(-0.09623807988697311)}
# Subgradient norm: 259.8790614862877
# End of iteration 11
#
# Start of iteration 12
# Current alpha: -8.908832472247088
# Current logL: -3258.5969136056638
# Updated alpha: -8.924485320890046
# Updated logL: -3258.464485667814
# New subgradient:
# {'Substitutions': Array([[-5.30122942e+01,  7.34343595e-02, -1.55226510e+01,
#         -1.37028132e+01],
#        [-2.81532505e+01, -1.58082598e+01, -2.39751811e+01,
#          2.50957788e+00],
#        [-2.67706804e+01,  3.61076122e+00,  1.63467703e+01,
#         -1.23709463e+00],
#        [-9.94831482e+00, -2.74473567e+01, -2.82546551e+01,
#          1.59139489e+02]],
#          alphabet='ACGT'), 'Gap opens': np.float64(140.81427960395231), 'Gap extends': np.float64(-87.06037544856454)}
# Stepsize: 1e-05
# Gap open step: 0.0014081427960395232
# Gap extend step: -0.0008706037544856455
# Match step: 0.001066657053838206
# Mismatch step: -0.0016881822397221901
# New parameters:
# {'alpha': np.float64(-8.924485320890046), 'match_score': np.float64(0.9770826580292709), 'mismatch_score': np.float64(-0.8665656793584973), 'open_gap_score': np.float64(-1.1787090405861247), 'extend_gap_score': np.float64(-0.09710868364145876)}
# Subgradient norm: 259.3941706434194
# End of iteration 12
#
# Start of iteration 13
# Current alpha: -8.924485320890046
# Current logL: -3257.8962273328993
# Updated alpha: -8.936117583872871
# Updated logL: -3257.8231618211694
# New subgradient:
# {'Substitutions': Array([[-46.00742484,  -1.98423628, -16.34565638, -13.14857274],
#        [-28.04230207, -18.04387733, -23.82944689,   2.6624111 ],
#        [-26.75173487,   2.23107356,  15.27359958,  -1.76041615],
#        [ -9.97829094, -28.71631521, -25.7003042 , 153.46215212]],
#          alphabet='ACGT'), 'Gap opens': np.float64(137.6274392896784), 'Gap extends': np.float64(-18.233835629166425)}
# Stepsize: 1e-05
# Gap open step: 0.001376274392896784
# Gap extend step: -0.00018233835629166426
# Match step: 0.0010468444954329099
# Mismatch step: -0.001713637910694978
# New parameters:
# {'alpha': np.float64(-8.936117583872871), 'match_score': np.float64(0.9781295025247038), 'mismatch_score': np.float64(-0.8682793172691923), 'open_gap_score': np.float64(-1.1773327661932278), 'extend_gap_score': np.float64(-0.09729102199775043)}
# Subgradient norm: 244.12735953407167
# End of iteration 13
#
# Start of iteration 14
# Current alpha: -8.936117583872871
# Current logL: -3257.3881291683424
# Updated alpha: -8.952809879955485
# Updated logL: -3257.2377621126043
# New subgradient:
# {'Substitutions': Array([[-56.03033172,  -0.81314912, -15.83419294, -13.46123507],
#        [-28.21946182, -20.4816971 , -23.12133113,   3.12964996],
#        [-26.711843  ,   3.02783588,  12.91677157,  -1.51695494],
#        [-10.40542201, -28.50812461, -26.85909211, 159.15097375]],
#          alphabet='ACGT'), 'Gap opens': np.float64(131.03291137259006), 'Gap extends': np.float64(-26.559756222504284)}
# Stepsize: 1e-05
# Gap open step: 0.0013103291137259007
# Gap extend step: -0.00026559756222504285
# Match step: 0.0009555571650015522
# Mismatch step: -0.001692933209306495
# New parameters:
# {'alpha': np.float64(-8.952809879955485), 'match_score': np.float64(0.9790850596897053), 'mismatch_score': np.float64(-0.8699722504784988), 'open_gap_score': np.float64(-1.1760224370795018), 'extend_gap_score': np.float64(-0.09755661955997547)}
# Subgradient norm: 235.93678810427556
# End of iteration 14
#
# Start of iteration 15
# Current alpha: -8.952809879955485
# Current logL: -3256.8039385069505
# Updated alpha: -8.96726122393163
# Updated logL: -3256.691314767181
# New subgradient:
# {'Substitutions': Array([[-56.3363685 ,  -1.2514256 , -15.69902608, -13.33088823],
#        [-28.04897938, -24.57064299, -22.95892701,   3.1987214 ],
#        [-27.26361402,   3.20017084,  13.33587976,  -0.42873759],
#        [-10.21891879, -28.29584304, -26.6648327 , 155.83285949]],
#          alphabet='ACGT'), 'Gap opens': np.float64(124.87048622890974), 'Gap extends': np.float64(-18.232512721920664)}
# Stepsize: 1e-05
# Gap open step: 0.0012487048622890976
# Gap extend step: -0.00018232512721920666
# Match step: 0.0008826172776035999
# Mismatch step: -0.0016776230020262638
# New parameters:
# {'alpha': np.float64(-8.96726122393163), 'match_score': np.float64(0.9799676769673089), 'mismatch_score': np.float64(-0.871649873480525), 'open_gap_score': np.float64(-1.1747737322172127), 'extend_gap_score': np.float64(-0.09773894468719467)}
# Subgradient norm: 227.72655709802353
# End of iteration 15
#
# Start of iteration 16
# Current alpha: -8.96726122393163
# Current logL: -3256.2917540551034
# Updated alpha: -8.981124168965412
# Updated logL: -3256.1881777965336
# New subgradient:
# {'Substitutions': Array([[-60.0814805 ,  -2.341372  , -16.19283173, -12.92881835],
#        [-28.55368284, -30.3188264 , -22.81177556,   2.36414679],
#        [-27.70168168,   5.45772563,   9.6774649 ,  -0.16320338],
#        [ -8.29244137, -28.68481274, -25.55202075, 155.92294279]],
#          alphabet='ACGT'), 'Gap opens': np.float64(115.18415141688331), 'Gap extends': np.float64(-35.02447078833566)}
# Stepsize: 1e-05
# Gap open step: 0.0011518415141688332
# Gap extend step: -0.00035024470788335663
# Match step: 0.0007520010078273797
# Mismatch step: -0.0016540076797762235
# New parameters:
# {'alpha': np.float64(-8.981124168965412), 'match_score': np.float64(0.9807196779751363), 'mismatch_score': np.float64(-0.8733038811603012), 'open_gap_score': np.float64(-1.1736218907030438), 'extend_gap_score': np.float64(-0.09808918939507803)}
# Subgradient norm: 217.9600227035951
# End of iteration 16
#
# Start of iteration 17
# Current alpha: -8.981124168965412
# Current logL: -3255.7771976360596
# Updated alpha: -8.991360494372875
# Updated logL: -3255.7207606404477
# New subgradient:
# {'Substitutions': Array([[-6.18385001e+01, -2.31258461e+00, -1.59520263e+01,
#         -1.27921897e+01],
#        [-2.80539399e+01, -3.11946606e+01, -2.20516468e+01,
#          2.54860409e+00],
#        [-2.60445761e+01,  5.54234457e+00,  5.67938084e+00,
#         -7.04683765e-02],
#        [-9.28076628e+00, -2.97737904e+01, -2.51247151e+01,
#          1.56012742e+02]],
#          alphabet='ACGT'), 'Gap opens': np.float64(110.89017328312029), 'Gap extends': np.float64(-49.69240765424666)}
# Stepsize: 1e-05
# Gap open step: 0.001108901732831203
# Gap extend step: -0.0004969240765424666
# Match step: 0.0006865896257884994
# Mismatch step: -0.001633657548994443
# New parameters:
# {'alpha': np.float64(-8.991360494372875), 'match_score': np.float64(0.9814062676009248), 'mismatch_score': np.float64(-0.8749375387092957), 'open_gap_score': np.float64(-1.1725129889702126), 'extend_gap_score': np.float64(-0.0985861134716205)}
# Subgradient norm: 214.8683060051098
# End of iteration 17
#
# Start of iteration 18
# Current alpha: -8.991360494372875
# Current logL: -3255.3058990388868
# Updated alpha: -8.999312897610212
# Updated logL: -3255.2718573286593
# New subgradient:
# {'Substitutions': Array([[-62.40176482,  -2.1982687 , -15.83185261, -12.19171691],
#        [-28.20092966, -31.89652814, -21.9121867 ,   2.71256383],
#        [-25.79477459,   5.70036924,   2.99248165,   1.35173635],
#        [ -8.83612902, -29.10779979, -24.71781749, 154.26342539]],
#          alphabet='ACGT'), 'Gap opens': np.float64(103.22155054306285), 'Gap extends': np.float64(-36.48378007211163)}
# Stepsize: 1e-05
# Gap open step: 0.0010322155054306285
# Gap extend step: -0.00036483780072111633
# Match step: 0.0006295761408311131
# Mismatch step: -0.0015902680604984287
# New parameters:
# {'alpha': np.float64(-8.999312897610212), 'match_score': np.float64(0.9820358437417559), 'mismatch_score': np.float64(-0.8765278067697941), 'open_gap_score': np.float64(-1.171480773464782), 'extend_gap_score': np.float64(-0.09895095127234162)}
# Subgradient norm: 203.07373271380175
# End of iteration 18
#
# Start of iteration 19
# Current alpha: -8.999312897610212
# Current logL: -3254.9056241710036
# Updated alpha: -9.007271468071956
# Updated logL: -3254.8715464253564
# New subgradient:
# {'Substitutions': Array([[-64.50157745,  -1.43588528, -15.25848437, -12.47792643],
#        [-27.99680766, -35.30515074, -20.15454426,   2.14009778],
#        [-26.02358487,   5.33753362,   0.18901449,   1.82126987],
#        [ -8.23344128, -28.01015601, -24.45434361, 153.03061107]],
#          alphabet='ACGT'), 'Gap opens': np.float64(94.62954063859814), 'Gap extends': np.float64(-52.218868157744836)}
# Stepsize: 1e-05
# Gap open step: 0.0009462954063859815
# Gap extend step: -0.0005221886815774484
# Match step: 0.0005341289736945044
# Mismatch step: -0.0015474627249187627
# New parameters:
# {'alpha': np.float64(-9.007271468071956), 'match_score': np.float64(0.9825699727154504), 'mismatch_score': np.float64(-0.8780752694947129), 'open_gap_score': np.float64(-1.1705344780583962), 'extend_gap_score': np.float64(-0.09947313995391907)}
# Subgradient norm: 196.16550820334726
# End of iteration 19
#
# Start of iteration 20
# Current alpha: -9.007271468071956
# Current logL: -3254.501447148524
# Updated alpha: -9.012297393321775
# Updated logL: -3254.487863865801
# New subgradient:
# {'Substitutions': Array([[-57.87137411,  -3.41618914, -15.55552807, -10.40913859],
#        [-29.11179074, -38.65329025, -19.55348891,   1.6678356 ],
#        [-25.44120871,   4.77735608,  -0.90274915,   2.66008562],
#        [ -8.98563317, -29.15953819, -24.09381602, 149.18657653]],
#          alphabet='ACGT'), 'Gap opens': np.float64(95.30441197949992), 'Gap extends': np.float64(-45.62717296138394)}
# Stepsize: 1e-05
# Gap open step: 0.0009530441197949992
# Gap extend step: -0.00045627172961383946
# Match step: 0.0005175916301447544
# Mismatch step: -0.0015662105422406716
# New parameters:
# {'alpha': np.float64(-9.012297393321775), 'match_score': np.float64(0.9830875643455952), 'mismatch_score': np.float64(-0.8796414800369536), 'open_gap_score': np.float64(-1.1695814339386013), 'extend_gap_score': np.float64(-0.0999294116835329)}
# Subgradient norm: 195.89266305153828
# End of iteration 20
#
# Start of iteration 21
# Current alpha: -9.012297393321775
# Current logL: -3254.1195995753847
# Updated alpha: -9.017617614054448
# Updated logL: -3254.104385665614
# New subgradient:
# {'Substitutions': Array([[-54.17546099,  -3.01589349, -16.14431594, -10.22842617],
#        [-29.16956495, -38.49863124, -19.36461637,   2.9482329 ],
#        [-26.57717877,   4.90632478,  -2.0440026 ,   2.16193328],
#        [ -9.31284144, -29.40492705, -23.3837971 , 144.90553534]],
#          alphabet='ACGT'), 'Gap opens': np.float64(94.45953326850682), 'Gap extends': np.float64(-38.07766460331716)}
# Stepsize: 1e-05
# Gap open step: 0.0009445953326850683
# Gap extend step: -0.0003807766460331716
# Match step: 0.0005018744050934175
# Mismatch step: -0.0015658507031555634
# New parameters:
# {'alpha': np.float64(-9.017617614054448), 'match_score': np.float64(0.9835894387506886), 'mismatch_score': np.float64(-0.8812073307401092), 'open_gap_score': np.float64(-1.1686368386059163), 'extend_gap_score': np.float64(-0.10031018832956608)}
# Subgradient norm: 193.41710213306706
# End of iteration 21
#
# Start of iteration 22
# Current alpha: -9.017617614054448
# Current logL: -3253.7546710572665
# Updated alpha: -9.023275641486713
# Updated logL: -3253.7374708862408
# New subgradient:
# {'Substitutions': Array([[-53.71723536,  -2.7976333 , -15.35161126,  -9.98226182],
#        [-28.93065326, -40.96282086, -20.15996009,   2.69762464],
#        [-26.98931289,   4.81811681,  -0.71216988,   1.67368417],
#        [ -7.91203209, -29.04120254, -22.18286482, 142.05580838]],
#          alphabet='ACGT'), 'Gap opens': np.float64(90.74945466062987), 'Gap extends': np.float64(-38.08997141749197)}
# Stepsize: 1e-05
# Gap open step: 0.0009074945466062988
# Gap extend step: -0.0003808997141749197
# Match step: 0.0004666358227837293
# Mismatch step: -0.0015415810644674637
# New parameters:
# {'alpha': np.float64(-9.023275641486713), 'match_score': np.float64(0.9840560745734723), 'mismatch_score': np.float64(-0.8827489118045766), 'open_gap_score': np.float64(-1.16772934405931), 'extend_gap_score': np.float64(-0.100691088043741)}
# Subgradient norm: 188.75518837394625
# End of iteration 22
#
# Start of iteration 23
# Current alpha: -9.023275641486713
# Current logL: -3253.3991228938853
# Updated alpha: -9.028301101215241
# Updated logL: -3253.3855592471136
# New subgradient:
# {'Substitutions': Array([[-53.76267765,  -2.68101113, -15.22374026,  -9.85477616],
#        [-28.69364289, -41.65852154, -20.01466567,   2.85918777],
#        [-26.65290711,   4.98848494,  -1.3150096 ,   1.94367961],
#        [ -7.76248025, -28.85685469, -22.02739388, 141.96657026]],
#          alphabet='ACGT'), 'Gap opens': np.float64(88.43681300471331), 'Gap extends': np.float64(-32.485783346740774)}
# Stepsize: 1e-05
# Gap open step: 0.0008843681300471332
# Gap extend step: -0.0003248578334674078
# Match step: 0.0004523036146755536
# Mismatch step: -0.0015197611972030825
# New parameters:
# {'alpha': np.float64(-9.028301101215241), 'match_score': np.float64(0.9845083781881478), 'mismatch_score': np.float64(-0.8842686730017797), 'open_gap_score': np.float64(-1.1668449759292627), 'extend_gap_score': np.float64(-0.1010159458772084)}
# Subgradient norm: 184.44219305194025
# End of iteration 23
#
# Start of iteration 24
# Current alpha: -9.028301101215241
# Current logL: -3253.062171102575
# Updated alpha: -9.03351031408936
# Updated logL: -3253.047602845334
# New subgradient:
# {'Substitutions': Array([[-51.009572  ,  -4.24729672, -14.05181492, -10.50210725],
#        [-29.75000833, -40.79735945, -18.08767377,   3.1281762 ],
#        [-25.54068007,   5.85709855,  -7.10180771,   1.65450921],
#        [-11.20741644, -29.39559538, -19.55819387, 140.2871156 ]],
#          alphabet='ACGT'), 'Gap opens': np.float64(85.86891858250485), 'Gap extends': np.float64(-31.56148598176548)}
# Stepsize: 1e-05
# Gap open step: 0.0008586891858250485
# Gap extend step: -0.0003156148598176548
# Match step: 0.00041378376449300734
# Mismatch step: -0.0015170100280933287
# New parameters:
# {'alpha': np.float64(-9.03351031408936), 'match_score': np.float64(0.9849221619526408), 'mismatch_score': np.float64(-0.885785683029873), 'open_gap_score': np.float64(-1.1659862867434376), 'extend_gap_score': np.float64(-0.10133156073702605)}
# Subgradient norm: 181.9202101660046
# End of iteration 24
#
# Start of iteration 25
# Current alpha: -9.03351031408936
# Current logL: -3252.729007026671
# Updated alpha: -9.038123783921513
# Updated logL: -3252.7175845149895
# New subgradient:
# {'Substitutions': Array([[-52.16116396,  -4.12861964, -13.92231775, -10.27393031],
#        [-29.49306412, -43.53687282, -18.3515989 ,   2.97677954],
#        [-27.00753632,   5.1197606 ,  -6.74914039,   1.83826312],
#        [-11.95871313, -29.19903986, -20.22375049, 139.45469778]],
#          alphabet='ACGT'), 'Gap opens': np.float64(84.6471248558577), 'Gap extends': np.float64(-24.021605028374793)}
# Stepsize: 1e-05
# Gap open step: 0.000846471248558577
# Gap extend step: -0.00024021605028374794
# Match step: 0.00037007520606536365
# Mismatch step: -0.001546237672721264
# New parameters:
# {'alpha': np.float64(-9.038123783921513), 'match_score': np.float64(0.9852922371587062), 'mismatch_score': np.float64(-0.8873319207025943), 'open_gap_score': np.float64(-1.165139815494879), 'extend_gap_score': np.float64(-0.1015717767873098)}
# Subgradient norm: 181.7147193855531
# End of iteration 25
#
# Start of iteration 26
# Current alpha: -9.038123783921513
# Current logL: -3252.402660240351
# Updated alpha: -9.04257787264266
# Updated logL: -3252.392016645374
# New subgradient:
# {'Substitutions': Array([[-52.44935518,  -3.28923289, -12.95155555, -10.55890402],
#        [-29.28558008, -43.55666832, -18.1935449 ,   3.1442977 ],
#        [-25.2132144 ,   5.45249352,  -8.08182175,   2.43221081],
#        [-12.72592746, -28.38618996, -20.00676359, 139.28228802]],
#          alphabet='ACGT'), 'Gap opens': np.float64(80.61214979607624), 'Gap extends': np.float64(-30.16613649094904)}
# Stepsize: 1e-05
# Gap open step: 0.0008061214979607625
# Gap extend step: -0.0003016613649094904
# Match step: 0.0003519444277680933
# Mismatch step: -0.001495819108309058
# New parameters:
# {'alpha': np.float64(-9.04257787264266), 'match_score': np.float64(0.9856441815864743), 'mismatch_score': np.float64(-0.8888277398109034), 'open_gap_score': np.float64(-1.1643336939969184), 'extend_gap_score': np.float64(-0.10187343815221929)}
# Subgradient norm: 176.12981387525156
# End of iteration 26
#
# Start of iteration 27
# Current alpha: -9.04257787264266
# Current logL: -3252.0928822093047
# Updated alpha: -9.046206996296153
# Updated logL: -3252.0858185060342
# New subgradient:
# {'Substitutions': Array([[-53.21164577,  -3.17079438, -12.82214321, -10.17301348],
#        [-29.12822803, -44.30198561, -17.79030745,   3.30422756],
#        [-24.99575385,   5.36572226,  -8.40183802,   2.61480242],
#        [-12.53727466, -28.16234785, -19.85428248, 138.73096012]],
#          alphabet='ACGT'), 'Gap opens': np.float64(77.25016236199123), 'Gap extends': np.float64(-25.048824652179263)}
# Stepsize: 1e-05
# Gap open step: 0.0007725016236199123
# Gap extend step: -0.00025048824652179266
# Match step: 0.0003281549071686233
# Mismatch step: -0.0014734939314713278
# New parameters:
# {'alpha': np.float64(-9.046206996296153), 'match_score': np.float64(0.9859723364936429), 'mismatch_score': np.float64(-0.8903012337423747), 'open_gap_score': np.float64(-1.1635611923732985), 'extend_gap_score': np.float64(-0.10212392639874109)}
# Subgradient norm: 171.41683491777113
# End of iteration 27
#
# Start of iteration 28
# Current alpha: -9.046206996296153
# Current logL: -3251.8005709354097
# Updated alpha: -9.049792436540256
# Updated logL: -3251.7936782292895
# New subgradient:
# {'Substitutions': Array([[-52.71695365,  -3.02389407, -12.69052239, -10.04557876],
#        [-28.64873327, -45.16801522, -17.70289012,   3.55129913],
#        [-24.74043843,   4.34509231,  -5.80960444,   2.1444139 ],
#        [-12.25891939, -27.96177686, -19.43956066, 137.68258434]],
#          alphabet='ACGT'), 'Gap opens': np.float64(77.10109598756615), 'Gap extends': np.float64(-11.291116022807483)}
# Stepsize: 1e-05
# Gap open step: 0.0007710109598756616
# Gap extend step: -0.00011291116022807483
# Match step: 0.0003398801102678768
# Mismatch step: -0.0014647150861552547
# New parameters:
# {'alpha': np.float64(-9.049792436540256), 'match_score': np.float64(0.9863122166039108), 'mismatch_score': np.float64(-0.8917659488285299), 'open_gap_score': np.float64(-1.1627901814134227), 'extend_gap_score': np.float64(-0.10223683755896916)}
# Subgradient norm: 169.35511811926258
# End of iteration 28
#
# Start of iteration 29
# Current alpha: -9.049792436540256
# Current logL: -3251.525261482204
# Updated alpha: -9.054654981471055
# Updated logL: -3251.512587023071
# New subgradient:
# {'Substitutions': Array([[-53.35616331,  -2.73673525, -12.4341346 ,  -9.81696279],
#        [-28.36586071, -45.74461982, -17.42924319,   4.25659297],
#        [-24.39997742,   4.46902195,  -5.90360598,   2.28831014],
#        [-12.0694199 , -27.30253008, -19.15862855, 136.95848312]],
#          alphabet='ACGT'), 'Gap opens': np.float64(72.94890115092396), 'Gap extends': np.float64(-8.851857304215931)}
# Stepsize: 1e-05
# Gap open step: 0.0007294890115092397
# Gap extend step: -8.851857304215932e-05
# Match step: 0.0003195409400593173
# Mismatch step: -0.0014269956743130081
# New parameters:
# {'alpha': np.float64(-9.054654981471055), 'match_score': np.float64(0.9866317575439701), 'mismatch_score': np.float64(-0.8931929445028429), 'open_gap_score': np.float64(-1.1620606924019135), 'extend_gap_score': np.float64(-0.10232535613201132)}
# Subgradient norm: 163.65857211182603
# End of iteration 29
#
# Start of iteration 30
# Current alpha: -9.054654981471055
# Current logL: -3251.2614941382863
# Updated alpha: -9.059321618216783
# Updated logL: -3251.2498232688613
# New subgradient:
# {'Substitutions': Array([[-53.97897426,  -2.3119934 , -11.84693061, -11.29360114],
#        [-27.59760612, -46.37781873, -17.1749136 ,   4.82942545],
#        [-23.91966636,   4.93832148,  -6.86866077,   3.25846103],
#        [-10.48152917, -27.03484874, -17.81323672, 136.51539318]],
#          alphabet='ACGT'), 'Gap opens': np.float64(68.03760880260843), 'Gap extends': np.float64(-26.136799802063678)}
# Stepsize: 1e-05
# Gap open step: 0.0006803760880260844
# Gap extend step: -0.0002613679980206368
# Match step: 0.00029289939425200133
# Mismatch step: -0.00136448117896699
# New parameters:
# {'alpha': np.float64(-9.059321618216783), 'match_score': np.float64(0.9869246569382222), 'mismatch_score': np.float64(-0.89455742568181), 'open_gap_score': np.float64(-1.1613803163138874), 'extend_gap_score': np.float64(-0.10258672413003196)}
# Subgradient norm: 157.44280848788648
# End of iteration 30
#
# Start of iteration 31
# Current alpha: -9.059321618216783
# Current logL: -3251.0076314193593
# Updated alpha: -9.062132519638364
# Updated logL: -3251.003398338151
# New subgradient:
# {'Substitutions': Array([[-54.15422336,  -2.20467855, -11.72827494, -11.17568423],
#        [-26.71797073, -49.52398726, -16.9979038 ,   5.2952888 ],
#        [-23.6924973 ,   4.5939773 ,  -5.29149463,   1.78807177],
#        [-10.33681087, -27.67469299, -17.62910402, 135.77334437]],
#          alphabet='ACGT'), 'Gap opens': np.float64(66.17612452155008), 'Gap extends': np.float64(-20.981627857714464)}
# Stepsize: 1e-05
# Gap open step: 0.0006617612452155009
# Gap extend step: -0.00020981627857714465
# Match step: 0.0002680363911993004
# Mismatch step: -0.001364802795672942
# New parameters:
# {'alpha': np.float64(-9.062132519638364), 'match_score': np.float64(0.9871926933294215), 'mismatch_score': np.float64(-0.8959222284774829), 'open_gap_score': np.float64(-1.1607185550686718), 'extend_gap_score': np.float64(-0.10279654040860911)}
# Subgradient norm: 155.45034559334226
# End of iteration 31
#
# Start of iteration 32
# Current alpha: -9.062132519638364
# Current logL: -3250.7708916248343
# Updated alpha: -9.064908157073175
# Updated logL: -3250.766765071973
# New subgradient:
# {'Substitutions': Array([[-53.30511964,  -2.09410072, -11.60434318, -11.04041768],
#        [-26.00362788, -49.75089832, -16.54674572,   5.78479874],
#        [-23.09337769,   4.77854731,  -5.53275372,   2.52563083],
#        [ -9.72567282, -27.40433229, -17.48747023, 136.92614738]],
#          alphabet='ACGT'), 'Gap opens': np.float64(64.36139389139088), 'Gap extends': np.float64(-18.607385595326154)}
# Stepsize: 1e-05
# Gap open step: 0.0006436139389139088
# Gap extend step: -0.00018607385595326156
# Match step: 0.0002833737570017091
# Mismatch step: -0.001319111113325596
# New parameters:
# {'alpha': np.float64(-9.064908157073175), 'match_score': np.float64(0.9874760670864232), 'mismatch_score': np.float64(-0.8972413395908085), 'open_gap_score': np.float64(-1.160074941129758), 'extend_gap_score': np.float64(-0.10298261426456237)}
# Subgradient norm: 150.639211286104
# End of iteration 32
#
# Start of iteration 33
# Current alpha: -9.064908157073175
# Current logL: -3250.5500635815442
# Updated alpha: -9.068112833293936
# Updated logL: -3250.5445640048883
# New subgradient:
# {'Substitutions': Array([[-53.48308912,  -1.98700674, -11.73982296, -11.02137799],
#        [-25.75898019, -50.53905169, -16.4156862 ,   6.02018701],
#        [-22.85879301,   4.92776001,  -8.58559256,   3.12719127],
#        [ -9.47741849, -26.61895909, -17.34927374, 135.91063953]],
#          alphabet='ACGT'), 'Gap opens': np.float64(59.10951664948215), 'Gap extends': np.float64(-24.698425310018454)}
# Stepsize: 1e-05
# Gap open step: 0.0005910951664948215
# Gap extend step: -0.00024698425310018453
# Match step: 0.00023302906171632928
# Mismatch step: -0.0012915218011913163
# New parameters:
# {'alpha': np.float64(-9.068112833293936), 'match_score': np.float64(0.9877090961481395), 'mismatch_score': np.float64(-0.8985328613919998), 'open_gap_score': np.float64(-1.159483845963263), 'extend_gap_score': np.float64(-0.10322959851766256)}
# Subgradient norm: 146.03855051628838
# End of iteration 33
#
# Start of iteration 34
# Current alpha: -9.068112833293936
# Current logL: -3250.3363573901274
# Updated alpha: -9.069918035029676
# Updated logL: -3250.3346127607538
# New subgradient:
# {'Substitutions': Array([[-55.28269899,  -1.88506039, -10.97833494, -11.28328074],
#        [-25.62712605, -51.13945652, -16.29295569,   6.08681336],
#        [-22.16287604,   5.21078046,  -9.41004008,   3.54477005],
#        [ -9.34126481, -26.45315783, -17.22059179, 135.44916582]],
#          alphabet='ACGT'), 'Gap opens': np.float64(54.02459172753625), 'Gap extends': np.float64(-20.24567311551509)}
# Stepsize: 1e-05
# Gap open step: 0.0005402459172753625
# Gap extend step: -0.0002024567311551509
# Match step: 0.0001961697023829136
# Mismatch step: -0.0012640228440657455
# New parameters:
# {'alpha': np.float64(-9.069918035029676), 'match_score': np.float64(0.9879052658505224), 'mismatch_score': np.float64(-0.8997968842360656), 'open_gap_score': np.float64(-1.1589436000459876), 'extend_gap_score': np.float64(-0.10343205524881771)}
# Subgradient norm: 140.3242916096776
# End of iteration 34
#
# Start of iteration 35
# Current alpha: -9.069918035029676
# Current logL: -3250.1453377154558
# Updated alpha: -9.071375911886806
# Updated logL: -3250.144200072094
# New subgradient:
# {'Substitutions': Array([[-55.35808579,  -1.78280453, -10.86470551, -11.17293265],
#        [-25.49482549, -51.37053489, -16.16874004,   6.21992802],
#        [-19.28490173,   5.35191144,  -9.69191529,   3.69667546],
#        [ -8.57538226, -25.57419412, -17.09149523, 134.0749187 ]],
#          alphabet='ACGT'), 'Gap opens': np.float64(48.539156320580275), 'Gap extends': np.float64(-21.112944376154353)}
# Stepsize: 1e-05
# Gap open step: 0.0004853915632058028
# Gap extend step: -0.00021112944376154355
# Match step: 0.00017654382739923778
# Mismatch step: -0.0012074146665127263
# New parameters:
# {'alpha': np.float64(-9.071375911886806), 'match_score': np.float64(0.9880818096779217), 'mismatch_score': np.float64(-0.9010042989025784), 'open_gap_score': np.float64(-1.158458208482782), 'extend_gap_score': np.float64(-0.10364318469257926)}
# Subgradient norm: 133.01122176558042
# End of iteration 35
#
# Start of iteration 36
# Current alpha: -9.071375911886806
# Current logL: -3249.970347146698
# Updated alpha: -9.072354907364494
# Updated logL: -3249.969834235838
# New subgradient:
# {'Substitutions': Array([[-55.40906276,  -1.68648032, -10.75822504, -10.91658643],
#        [-25.29535024, -51.91585061, -15.97739664,   6.34617058],
#        [-18.82381468,   5.48500659,  -9.60534143,   3.97559823],
#        [ -8.09130837, -25.27917244, -16.97074513, 133.73801584]],
#          alphabet='ACGT'), 'Gap opens': np.float64(46.133851075632435), 'Gap extends': np.float64(-20.89076827108185)}
# Stepsize: 1e-05
# Gap open step: 0.0004613385107563244
# Gap extend step: -0.00020890768271081853
# Match step: 0.00016807761040397653
# Mismatch step: -0.0011799230389624323
# New parameters:
# {'alpha': np.float64(-9.072354907364494), 'match_score': np.float64(0.9882498872883256), 'mismatch_score': np.float64(-0.9021842219415408), 'open_gap_score': np.float64(-1.1579968699720256), 'extend_gap_score': np.float64(-0.10385209237529007)}
# Subgradient norm: 129.49687650271414
# End of iteration 36
#
# Start of iteration 37
# Current alpha: -9.072354907364494
# Current logL: -3249.8053228141216
# Updated alpha: -9.073178692229185
# Updated logL: -3249.8049597112467
# New subgradient:
# {'Substitutions': Array([[-55.10545275,  -1.55713771, -10.38800603, -10.81420614],
#        [-25.17170873, -51.6794719 , -15.59762535,   6.73541177],
#        [-18.63502325,   5.8344868 , -10.34921524,   4.15084081],
#        [ -7.81642288, -25.28129348, -16.73532188, 133.88673968]],
#          alphabet='ACGT'), 'Gap opens': np.float64(43.962849508672335), 'Gap extends': np.float64(-15.696011835525212)}
# Stepsize: 1e-05
# Gap open step: 0.00043962849508672337
# Gap extend step: -0.00015696011835525213
# Match step: 0.00016752599797616868
# Mismatch step: -0.0011527600607713065
# New parameters:
# {'alpha': np.float64(-9.073178692229185), 'match_score': np.float64(0.9884174132863018), 'mismatch_score': np.float64(-0.903336982002312), 'open_gap_score': np.float64(-1.1575572414769388), 'extend_gap_score': np.float64(-0.10400905249364532)}
# Subgradient norm: 125.49224717701446
# End of iteration 37
#
# Start of iteration 38
# Current alpha: -9.073178692229185
# Current logL: -3249.649529250468
# Updated alpha: -9.07437059334669
# Updated logL: -3249.6487692499895
# New subgradient:
# {'Substitutions': Array([[-55.1723601 ,  -1.46354088, -10.28389403, -10.71323812],
#        [-25.05057676, -51.8703421 , -15.48369015,   6.85560294],
#        [-18.44021358,   5.96450715, -10.59297913,   4.28991063],
#        [ -7.68427108, -25.12246123, -16.61730175, 133.84218132]],
#          alphabet='ACGT'), 'Gap opens': np.float64(42.64308468551603), 'Gap extends': np.float64(-14.720211376181796)}
# Stepsize: 1e-05
# Gap open step: 0.0004264308468551603
# Gap extend step: -0.00014720211376181798
# Match step: 0.000162064999876239
# Mismatch step: -0.0011374916683272228
# New parameters:
# {'alpha': np.float64(-9.07437059334669), 'match_score': np.float64(0.9885794782861781), 'mismatch_score': np.float64(-0.9044744736706393), 'open_gap_score': np.float64(-1.1571308106300837), 'extend_gap_score': np.float64(-0.10415625460740714)}
# Subgradient norm: 123.43678905189856
# End of iteration 38
#
# Start of iteration 39
# Current alpha: -9.07437059334669
# Current logL: -3249.494313970232
# Updated alpha: -9.075536810234352
# Updated logL: -3249.493586487213
# New subgradient:
# {'Substitutions': Array([[-56.85207637,  -2.57821777, -10.4490293 , -11.73172786],
#        [-25.55763515, -51.66941859, -15.9040148 ,   6.4702791 ],
#        [-19.2422727 ,   3.08759322, -12.37831788,   2.50156261],
#        [ -8.6764216 , -24.38396222, -16.60424565, 130.06639771]],
#          alphabet='ACGT'), 'Gap opens': np.float64(42.78426424686075), 'Gap extends': np.float64(2.329574784849399)}
# Stepsize: 1e-05
# Gap open step: 0.00042784264246860756
# Gap extend step: 2.329574784849399e-05
# Match step: 9.166584866588068e-05
# Mismatch step: -0.0012306809212832097
# New parameters:
# {'alpha': np.float64(-9.075536810234352), 'match_score': np.float64(0.988671144134844), 'mismatch_score': np.float64(-0.9057051545919225), 'open_gap_score': np.float64(-1.156702967987615), 'extend_gap_score': np.float64(-0.10413295885955864)}
# Subgradient norm: 130.63575989768142
# End of iteration 39
#
# Start of iteration 40
# Current alpha: -9.075536810234352
# Current logL: -3249.3255216528814
# Updated alpha: -9.076852227956486
# Updated logL: -3249.324596192977
# New subgradient:
# {'Substitutions': Array([[-57.12753196,  -2.46841178, -10.31774593, -11.61640981],
#        [-25.41298297, -51.89215148, -15.76202231,   6.60767321],
#        [-18.9892044 ,   3.24334633, -12.71395222,   2.66354486],
#        [ -8.50029298, -24.16873417, -16.46188298, 129.71229781]],
#          alphabet='ACGT'), 'Gap opens': np.float64(40.92536866878859), 'Gap extends': np.float64(-2.3618384014019838)}
# Stepsize: 1e-05
# Gap open step: 0.00040925368668788596
# Gap extend step: -2.361838401401984e-05
# Match step: 7.978662155064541e-05
# Mismatch step: -0.00121183122930774
# New parameters:
# {'alpha': np.float64(-9.076852227956486), 'match_score': np.float64(0.9887509307563946), 'mismatch_score': np.float64(-0.9069169858212303), 'open_gap_score': np.float64(-1.156293714300927), 'extend_gap_score': np.float64(-0.10415657724357266)}
# Subgradient norm: 128.17750354235466
# End of iteration 40
#
# Start of iteration 41
# Current alpha: -9.076852227956486
# Current logL: -3249.162148994932
# Updated alpha: -9.077574915778207
# Updated logL: -3249.1618696826804
# New subgradient:
# {'Substitutions': Array([[-57.29713339,  -2.36242844, -10.19233417, -11.50378275],
#        [-25.27405626, -52.04371629, -15.62658029,   6.78565716],
#        [-18.75147058,   3.3930802 , -12.91944498,   2.81985517],
#        [ -8.33561863, -23.92396388, -16.28211368, 129.55812374]],
#          alphabet='ACGT'), 'Gap opens': np.float64(39.2947330092011), 'Gap extends': np.float64(-5.101660846176642)}
# Stepsize: 1e-05
# Gap open step: 0.00039294733009201106
# Gap extend step: -5.1016608461766426e-05
# Match step: 7.29782908221219e-05
# Mismatch step: -0.0011925375616339184
# New parameters:
# {'alpha': np.float64(-9.077574915778207), 'match_score': np.float64(0.9888239090472167), 'mismatch_score': np.float64(-0.9081095233828642), 'open_gap_score': np.float64(-1.155900766970835), 'extend_gap_score': np.float64(-0.10420759385203443)}
# Subgradient norm: 125.87620765674785
# End of iteration 41
#
# Start of iteration 42
# Current alpha: -9.077574915778207
# Current logL: -3249.0030081443583
# Updated alpha: -9.07795011322406
# Updated logL: -3249.0029328664095
# New subgradient:
# {'Substitutions': Array([[-57.43421449,  -2.25453703, -10.7053386 , -11.80011346],
#        [-25.27878864, -51.32535015, -16.11599291,   6.09133432],
#        [-19.14940517,   3.53813872, -13.35775319,   2.78280514],
#        [ -7.99563978, -23.45185813, -15.20802405, 128.8404058 ]],
#          alphabet='ACGT'), 'Gap opens': np.float64(39.58848930346903), 'Gap extends': np.float64(-8.808952520991378)}
# Stepsize: 1e-05
# Gap open step: 0.00039588489303469035
# Gap extend step: -8.808952520991378e-05
# Match step: 6.723087970942928e-05
# Mismatch step: -0.0011954741956775503
# New parameters:
# {'alpha': np.float64(-9.07795011322406), 'match_score': np.float64(0.9888911399269261), 'mismatch_score': np.float64(-0.9093049975785418), 'open_gap_score': np.float64(-1.1555048820778002), 'extend_gap_score': np.float64(-0.10429568337724435)}
# Subgradient norm: 126.41847794931662
# End of iteration 42
#
# Start of iteration 43
# Current alpha: -9.07795011322406
# Current logL: -3248.8427108287224
# Updated alpha: -9.077951803516868
# Updated logL: -3248.842710827195
# New subgradient:
# {'Substitutions': Array([[-59.43686829,  -1.86362037, -10.30557639, -11.01519937],
#        [-25.14764144, -49.14954864, -15.98991964,   6.18143102],
#        [-18.93063784,   3.68111645, -17.40485357,   2.93340988],
#        [ -8.78705119, -23.28034834, -18.37181867, 130.64906228]],
#          alphabet='ACGT'), 'Gap opens': np.float64(37.64328756506768), 'Gap extends': np.float64(7.494401939704639)}
# Stepsize: 1e-05
# Gap open step: 0.00037643287565067686
# Gap extend step: 7.49440193970464e-05
# Match step: 4.657791781609973e-05
# Mismatch step: -0.0012089585589191167
# New parameters:
# {'alpha': np.float64(-9.077951803516868), 'match_score': np.float64(0.9889377178447423), 'mismatch_score': np.float64(-0.9105139561374609), 'open_gap_score': np.float64(-1.1551284492021496), 'extend_gap_score': np.float64(-0.1042207393578473)}
# Subgradient norm: 126.92787777024766
# End of iteration 43
#
# Start of iteration 44
# Current alpha: -9.077951803516868
# Current logL: -3248.654591820245
# Updated alpha: -9.078883689093445
# Updated logL: -3248.654127496763
# New subgradient:
# {'Substitutions': Array([[-61.99194403,  -3.12773852, -11.36136615, -13.7358777 ],
#        [-25.54992464, -49.56383575, -17.19950308,   3.801952  ],
#        [-21.03791783,   1.93672136, -15.74359994,   2.1796935 ],
#        [-11.47961744, -25.77229212, -18.22804316, 129.56785568]],
#          alphabet='ACGT'), 'Gap opens': np.float64(48.9701471562913), 'Gap extends': np.float64(23.343677226709215)}
# Stepsize: 1e-05
# Gap open step: 0.000489701471562913
# Gap extend step: 0.00023343677226709216
# Match step: 2.26847595195342e-05
# Mismatch step: -0.0013957391377257238
# New parameters:
# {'alpha': np.float64(-9.078883689093445), 'match_score': np.float64(0.9889604026042618), 'mismatch_score': np.float64(-0.9119096952751866), 'open_gap_score': np.float64(-1.1546387477305866), 'extend_gap_score': np.float64(-0.10398730258558021)}
# Subgradient norm: 149.76323303104692
# End of iteration 44
#
# Start of iteration 45
# Current alpha: -9.078883689093445
# Current logL: -3248.433613500596
# Updated alpha: -9.0808566823317
# Updated logL: -3248.4315320856194
# New subgradient:
# {'Substitutions': Array([[-61.93589848,  -3.62305945, -12.00900749, -15.43760852],
#        [-25.16164387, -53.21083492, -16.7463534 ,   4.2974202 ],
#        [-20.93479572,   2.12976417, -16.44262397,   2.16566757],
#        [-11.31628298, -25.70273913, -17.96893155, 128.29710276]],
#          alphabet='ACGT'), 'Gap opens': np.float64(46.53313276332917), 'Gap extends': np.float64(3.7683732776714334)}
# Stepsize: 1e-05
# Gap open step: 0.00046533132763329173
# Gap extend step: 3.768373277671434e-05
# Match step: -3.292254611361017e-05
# Mismatch step: -0.0014030757016936179
# New parameters:
# {'alpha': np.float64(-9.0808566823317), 'match_score': np.float64(0.9889274800581481), 'mismatch_score': np.float64(-0.9133127709768802), 'open_gap_score': np.float64(-1.1541734164029533), 'extend_gap_score': np.float64(-0.1039496188528035)}
# Subgradient norm: 147.90735704888345
# End of iteration 45
#
# Start of iteration 46
# Current alpha: -9.0808566823317
# Current logL: -3248.213458451816
# Updated alpha: -9.080322126816444
# Updated logL: -3248.213305670442
# New subgradient:
# {'Substitutions': Array([[-61.27808816,  -3.49727443, -12.08779394, -15.27805356],
#        [-24.99929446, -51.7104764 , -16.9641123 ,   3.78579684],
#        [-20.65313889,   2.32267598, -15.90031207,   2.35072467],
#        [-11.12551153, -25.45628027, -17.38344407, 127.46296029]],
#          alphabet='ACGT'), 'Gap opens': np.float64(47.22943214154797), 'Gap extends': np.float64(2.280878749637333)}
# Stepsize: 1e-05
# Gap open step: 0.00047229432141547974
# Gap extend step: 2.2808787496373334e-05
# Match step: -1.4259163339540068e-05
# Mismatch step: -0.001389857059683727
# New parameters:
# {'alpha': np.float64(-9.080322126816444), 'match_score': np.float64(0.9889132208948086), 'mismatch_score': np.float64(-0.914702628036564), 'open_gap_score': np.float64(-1.1537011220815379), 'extend_gap_score': np.float64(-0.10392681006530713)}
# Subgradient norm: 146.8158076271149
# End of iteration 46
#
# Start of iteration 47
# Current alpha: -9.080322126816444
# Current logL: -3247.9987578073324
# Updated alpha: -9.080000370331156
# Updated logL: -3247.9987024553693
# New subgradient:
# {'Substitutions': Array([[-62.52707347,  -4.03929396, -12.60319524, -15.15466999],
#        [-25.50512203, -51.91565566, -16.8142083 ,   3.27313561],
#        [-20.11539155,   2.49766513, -16.849957  ,   2.65284935],
#        [-10.92385065, -25.2155851 , -17.22729802, 125.27053128]],
#          alphabet='ACGT'), 'Gap opens': np.float64(44.30502298879856), 'Gap extends': np.float64(-6.811078762841251)}
# Stepsize: 1e-05
# Gap open step: 0.00044305022988798566
# Gap extend step: -6.811078762841252e-05
# Match step: -6.0221548537566896e-05
# Mismatch step: -0.0013917496475156581
# New parameters:
# {'alpha': np.float64(-9.080000370331156), 'match_score': np.float64(0.988852999346271), 'mismatch_score': np.float64(-0.9160943776840796), 'open_gap_score': np.float64(-1.1532580718516499), 'extend_gap_score': np.float64(-0.10399492085293555)}
# Subgradient norm: 146.3395470084345
# End of iteration 47
#
# Start of iteration 48
# Current alpha: -9.080000370331156
# Current logL: -3247.7902756099925
# Updated alpha: -9.078144493019082
# Updated logL: -3247.7884341636236
# New subgradient:
# {'Substitutions': Array([[-62.45773761,  -3.76137348, -12.40713814, -15.25187565],
#        [-24.98798814, -52.09805584, -16.39966725,   3.47537843],
#        [-19.71675297,   2.91051398, -16.60534992,   3.36503562],
#        [-10.47563765, -24.52733127, -17.22372148, 126.5809296 ]],
#          alphabet='ACGT'), 'Gap opens': np.float64(42.031349081491776), 'Gap extends': np.float64(-4.350664351762273)}
# Stepsize: 1e-05
# Gap open step: 0.0004203134908149178
# Gap extend step: -4.3506643517622734e-05
# Match step: -4.5802137671407626e-05
# Mismatch step: -0.001350005580040791
# New parameters:
# {'alpha': np.float64(-9.078144493019082), 'match_score': np.float64(0.9888071972085997), 'mismatch_score': np.float64(-0.9174443832641205), 'open_gap_score': np.float64(-1.152837758360835), 'extend_gap_score': np.float64(-0.10403842749645317)}
# Subgradient norm: 141.53335863137477
# End of iteration 48
#
# Start of iteration 49
# Current alpha: -9.078144493019082
# Current logL: -3247.590953082441
# Updated alpha: -9.076686064854393
# Updated logL: -3247.5898159054714
# New subgradient:
# {'Substitutions': Array([[-62.35418745,  -3.64733219, -12.26714524, -15.19945774],
#        [-24.83915082, -52.16556836, -16.20377463,   3.62054178],
#        [-19.35295016,   3.07480274, -16.72965958,   3.57118947],
#        [-10.29229778, -24.31016116, -17.0788876 , 126.7191927 ]],
#          alphabet='ACGT'), 'Gap opens': np.float64(40.7118961676151), 'Gap extends': np.float64(-7.207057594042003)}
# Stepsize: 1e-05
# Gap open step: 0.000407118961676151
# Gap extend step: -7.207057594042004e-05
# Match step: -4.530222683480148e-05
# Mismatch step: -0.0013292462331982746
# New parameters:
# {'alpha': np.float64(-9.076686064854393), 'match_score': np.float64(0.9887618949817648), 'mismatch_score': np.float64(-0.9187736294973188), 'open_gap_score': np.float64(-1.1524306393991588), 'extend_gap_score': np.float64(-0.10411049807239359)}
# Subgradient norm: 139.2798570181864
# End of iteration 49

# %%
print(params['final_loglik'])
# Out:
# -3247.4010792323706

# %%
print(params['final_loglik'])
# Out:
# -3247.4010792323706

# %%
plt.figure()
plt.subplot(221)
plt.plot(np.arange(NITER), params['subgradient_l2_trajectory'])
plt.plot([0, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')


plt.subplot(222)
plt.plot(np.arange(NITER+1), params['loglik_trajectory'])
plt.plot([0, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')

plt.subplot(223)
plt.plot(np.arange(NITER//2, NITER), params['subgradient_l2_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')

plt.subplot(224)
plt.plot(np.arange(NITER//2, NITER+1), params['loglik_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')

plt.tight_layout()

# %%
plt.figure()
plt.subplot(221)
plt.plot(np.arange(NITER), params['subgradient_l2_trajectory'])
plt.plot([0, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')


plt.subplot(222)
plt.plot(np.arange(NITER+1), params['loglik_trajectory'])
plt.plot([0, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')

plt.subplot(223)
plt.plot(np.arange(NITER//2, NITER), params['subgradient_l2_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER], [0, 0], 'k--')
plt.title('Subgradient L2 norm trajectory')

plt.subplot(224)
plt.plot(np.arange(NITER//2, NITER+1), params['loglik_trajectory'][NITER//2:])
plt.plot([NITER//2, NITER+1], [true_logL, true_logL], 'k--')
plt.title('LogLikelihood trajectory')

plt.tight_layout()

# %%
print(true_match, params['match_score'])
print(true_mismatch, params['mismatch_score'])
print(true_gapopen, params['open_gap_score'])
print(true_gapext, params['extend_gap_score'])
print(true_alpha, params['alpha'])
# Out:
# 1 0.9887618949817648
# -1 -0.9187736294973188
# -1.2 -1.1524306393991588
# -0.1 -0.10411049807239359
# -9 -9.076686064854393

# %% [markdown]
# ### Parameter Convergence Experiment

# %%
theta = params['theta_trajectory']
theta_star = np.array([true_match, true_mismatch, true_gapopen, true_gapext]) ## what we try to estimate
loglik = np.array(params['loglik_trajectory'])

# ||theta_n - theta*||
theta_diff = []
for theta_n in theta: 
    diff = np.linalg.norm(theta_n - theta_star)
    theta_diff.append(diff)

theta_diff = np.array(theta_diff)

# %%
# ||theta_n - theta*|| vs n
plt.figure(figsize=FIGSIZE)

plt.plot(range(len(theta_diff)), theta_diff)

plt.xlabel("n")
plt.ylabel(r"$\|\theta_n - \theta^*\|$")

plt.tight_layout()
plt.show()

# %%
# ||theta_n - theta*|| vs log-likelihood

plt.figure(figsize=FIGSIZE)

plt.plot(loglik, theta_diff)

plt.xlabel("Log-likelihood")
plt.ylabel(r"$\|\theta_n - \theta^*\|$")

plt.tight_layout()
plt.show()

# %%
# ||theta_n - theta*|| vs ||theta_{n+1} - theta_n||
theta_nplusone = []
for n in range(len(theta) - 1):
    plusone = np.linalg.norm(theta[n+1] - theta[n])
    theta_nplusone.append(plusone)

theta_nplusone = np.array(theta_nplusone)

plt.figure(figsize=FIGSIZE)

plt.plot(theta_nplusone, theta_diff[:-1])

plt.xlabel(r"$\|\theta_{n+1} - \theta_n\|$")
plt.ylabel(r"$\|\theta_n - \theta^*\|$")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step function parameters experiment

# %%
labels = rd.rand(len(mirlist)) <= logit_scores

# %%
true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))

# %%
steplengths = np.linspace(0.000005, 0.00005, num=10)
steplengths
# Out:
# array([5.0e-06, 1.0e-05, 1.5e-05, 2.0e-05, 2.5e-05, 3.0e-05, 3.5e-05,
#        4.0e-05, 4.5e-05, 5.0e-05])

# %%
NITER = 200

# %%
# Get the iteration at which logL is hit (speed)
def get_logL__reached_iter(params, true_logL):
    for i, logL in enumerate(params['loglik_trajectory']):
        if logL >= true_logL:
            return i
    return None

# %%
# Get the value at the last iteration of the simulation
def get_final_val_avg(params):
    return np.mean(params['loglik_trajectory'][-20:])

# %%
pickle_path = "results/simple/step_experiment_simple.pkl"

if os.path.exists(pickle_path):
    with open(pickle_path, "rb") as f:
        saved = pickle.load(f)

    labels = saved["labels"]
    true_logL = saved["true_logL"]
    discrimalign_results_step = saved["discrimalign_results_step"]
    logL_reached_iters = saved["logL_reached_iters"]
    final_vals = saved["final_vals"]

else:
    
    labels = rd.rand(len(mirlist)) <= logit_scores
    true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
    
    discrimalign_results_step = []

    logL_reached_iters = []
    final_vals = []

    for stepl in steplengths:
        const_step = create_constant_step(stepl)
        
        params = discrimalign(mirlist, genelist, labels, 
                        stepfunction=const_step,
                        aligner_mode='local',
                        substitution_mode='simple',
                        gap_mode = 'affine',
                        verbose=False, max_iter=NITER,
                        stochastic_factor=0.001,
                        num_threads = 16)
        discrimalign_results_step.append(params)

        logL_reached_iter = get_logL__reached_iter(params, true_logL)
        logL_reached_iters.append(logL_reached_iter if logL_reached_iter is not None else np.inf) # infinity so that they dont show on the scatter plot 

        final_val = get_final_val_avg(params)
        final_vals.append(final_val)

        if logL_reached_iter is not None:
            print(f"step {stepl:.2e}, surpassed logL at iteration {logL_reached_iter} and reached a maximum value of {final_val}")
        else:
            print(f"step {stepl:.2e} did NOT hit logL")
    
    with open(pickle_path, "wb") as f:
        pickle.dump(
            {
                "labels": labels,
                "true_logL": true_logL,
                "discrimalign_results_step": discrimalign_results_step,
                "logL_reached_iters": logL_reached_iters,
                "final_vals": final_vals,
                "steplengths": steplengths,
                "NITER": NITER,
            },
            f
        )

# %%
from matplotlib.lines import Line2D

step_colors = plt.cm.tab10(np.linspace(0, 1, len(steplengths)))

legend_handles = [
    Line2D(
        [0], [0],
        color=color,
        lw=2.5,
        label=f"{stepl:.1e}"
    )
    for stepl, color in zip(steplengths, step_colors)
]

legend_handles.append(
    Line2D(
        [0], [0],
        color="k",
        linestyle="--",
        lw=1.8,
        label="True log-likelihood"
    )
)

fig = plt.figure(figsize=(5.5, 0.65))

ax = fig.add_subplot(111)
ax.axis("off")

ax.legend(
    handles=legend_handles,
    title="Step length",
    loc="center",
    ncol=11,
    frameon=False,
    handlelength=2.2,
    columnspacing=1.1,
    handletextpad=0.45,
    borderaxespad=0.0
)

plt.tight_layout(pad=0.1)
plt.savefig("results/step_length_legend.png", dpi=DPI, bbox_inches="tight")
plt.plot()
# Out:
# /tmp/ipykernel_38997/3464062125.py:42: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout(pad=0.1)
# []

# %%
plt.figure(figsize=FIGSIZE)
for params,color in zip(discrimalign_results_step, step_colors):
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
plt.plot([0, NITER], [true_logL, true_logL], 'k--')

plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")
ax = plt.gca()
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_xticks(np.linspace(0, 200, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))
plt.tight_layout()
plt.savefig("results/simple/step_experiment_full_trajectories_simple.png", dpi=DPI)

# %%
# zoom on start
plt.figure(figsize=FIGSIZE)
for params,color in zip(discrimalign_results_step, step_colors):
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
plt.plot([0, NITER], [true_logL, true_logL], 'k--')

plt.xlim(0, 15)
plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")

ax = plt.gca()

ax.set_xticks(np.linspace(0, 15, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.tight_layout()
plt.savefig("results/simple/step_experiment_zoom_start_simple.png", dpi=DPI)

# %%
# # zoom where most trajectories hit logL
# plt.figure(figsize=FIGSIZE)
# for params,color in zip(discrimalign_results_step, step_colors):
#     plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)
# plt.plot([0, NITER], [true_logL, true_logL], 'k--')

# plt.xlim(25, NITER) 
# all_vals = np.concatenate([
#     np.array(p['loglik_trajectory'])[25:]
#     for p in discrimalign_results_step
# ])

# ymin, ymax = all_vals.min(), all_vals.max()
# plt.ylim(ymin, 0.99 * ymax)

# plt.xlabel("Iteration")
# plt.ylabel("Log-likelihood")
# ax = plt.gca()
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# plt.tight_layout()
# plt.savefig("results/simple/step_experiment_zoom_mid_simple.png", dpi=DPI)

# %%
# zoom on the end of the iterations

plt.figure(figsize=FIGSIZE)
for plotid, params,color in zip(range(len(discrimalign_results_step)), discrimalign_results_step, step_colors):
    if plotid == 9: continue
    plt.plot(np.arange(NITER+1), params['loglik_trajectory'],color = color, alpha=0.7)

plt.plot([0, NITER], [true_logL, true_logL], 'k--')


plt.xlim(NITER-20, NITER)

# collect only last 20 iterations
all_vals = np.concatenate([
    np.array(p['loglik_trajectory'])[NITER-20:]
    for p in discrimalign_results_step
])

#sort and drop lowest x % 
sorted_vals = np.sort(all_vals)
cutoff = int(0.3 * len(sorted_vals))  # remove lowest x%
trimmed_vals = sorted_vals[cutoff:]

ymin = trimmed_vals.min()
ymax = trimmed_vals.max()

pad = 0.05 * (ymax - ymin)

plt.ylim(ymin, ymax + pad)

ax = plt.gca()
ax.set_xticks(np.linspace(180, 200, 5, dtype=int))
ax.set_yticks(np.linspace(*ax.get_ylim(), 4))

ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))


plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")
plt.tight_layout()
plt.savefig("results/simple/step_experiment_zoom_end_simple.png", dpi=DPI)

# %%
plt.figure(figsize=FIGSIZE)

logL_reached_iters_arr = np.array(logL_reached_iters)
final_vals_arr = np.array(final_vals)
steplengths_arr = np.array(steplengths)

mask = np.isfinite(logL_reached_iters_arr)

# Get unique step sizes
unique_steps = np.sort(np.unique(steplengths_arr[mask]))

# Use a discrete colormap
cmap = plt.cm.get_cmap("tab10", len(unique_steps))

for i, s in enumerate(unique_steps):
    idx = (steplengths_arr == s) & mask

    plt.scatter(
        final_vals_arr[idx],
        logL_reached_iters_arr[idx],
        color=cmap(i),
        s=60,
        label=f"{s:.2e}",
        alpha=0.85
    )

plt.ylabel("First Iteration which hits true logL")
plt.xlabel("Average logL at last 20 iterations")


ax = plt.gca()
xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(xmin, xmax, 5))
ax.set_xlim(xmin, xmax)
ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))


plt.tight_layout()
plt.savefig("results/simple/step_experiment_scatter_hit_vs_final_simple.png", dpi=DPI)
# Out:
# /tmp/ipykernel_38997/3503067501.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(unique_steps))

# %% [markdown]
# ### Replicates

# %%
REPS = 20 #20
NITER = 200

# %%
const_step = create_constant_step(2.0e-05) # choose best step from prev exp 
# const_step = create_constant_step(0.00001)
# powerstep = create_powerstep(0.00001, power=0.5, burnin=0)
# powerstep = create_powerstep(0.00001, power=-0.5, burnin=0)

# %%
# Checks if the chosen step size is stable in convergence across different datasets
pickle_path = "results/simple/replicates_simple.pkl"

if os.path.exists(pickle_path):
    with open(pickle_path, "rb") as f:
        saved = pickle.load(f)

    discrimalign_results_rep = saved["discrimalign_results_rep"]
    true_logLs = saved["true_logLs"]
    logL_reached_iters_rep = saved["logL_reached_iters_rep"]
    final_vals_rep = saved["final_vals_rep"]

else:

    discrimalign_results_rep = []
    true_logLs = []

    logL_reached_iters_rep = []
    final_vals_rep = []

    for _ in range(REPS):
        labels = rd.rand(len(mirlist)) <= logit_scores
        true_logL = np.sum(np.log(logit_scores[labels]))+np.sum(np.log(1-logit_scores[~labels]))
        true_logLs.append(true_logL)
        params = discrimalign(mirlist, genelist, labels, 
                        stepfunction=const_step,
                        aligner_mode='local',
                        substitution_mode='simple',
                        gap_mode = 'affine',
                        verbose=False, max_iter=NITER,
                        stochastic_factor=0.001,
                        num_threads = 16)
        discrimalign_results_rep.append(params)

        logL_reached_iter = get_logL__reached_iter(params, true_logL)
        
        logL_reached_iters_rep.append(
            logL_reached_iter if logL_reached_iter is not None else np.inf
        )

        final_vals_rep.append(get_final_val_avg(params))

    for i, it in enumerate(logL_reached_iters_rep):
        if np.isfinite(it):
            print(f"rep {i} hit logL at iteration {it}, final={final_vals_rep[i]:.2f}")
        else:
            print(f"rep {i} did NOT hit logL, final={final_vals_rep[i]:.2f}")

    with open(pickle_path, "wb") as f:
        pickle.dump(
            {
                "discrimalign_results_rep": discrimalign_results_rep,
                "true_logLs": true_logLs,
                "logL_reached_iters_rep": logL_reached_iters_rep,
                "final_vals_rep": final_vals_rep,
                "REPS": REPS,
                "NITER": NITER,
            },
            f
        )

# %%
plt.figure(figsize=FIGSIZE)

for params in discrimalign_results_rep:
    plt.plot(
        np.arange(NITER + 1),
        params['loglik_trajectory'],
        alpha=0.2,
        color='b'
    )

plt.xlabel("Iteration")
plt.ylabel("Log-likelihood")
ax = plt.gca()
xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(xmin, xmax, 5))
ax.set_xlim(xmin, xmax)

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))

plt.tight_layout()
plt.savefig("results/simple/replicates_loglik_trajectories_simple.png", dpi=DPI)

# %%
plt.figure(figsize=FIGSIZE)

plt.plot([0, NITER], [0, 0], 'k--')

for params, tlL in zip(discrimalign_results_rep, true_logLs):
    plt.plot(
        np.arange(NITER + 1),
        tlL - np.array(params['loglik_trajectory']),
        alpha=0.2,
        color='b'
    )

plt.xlabel("Iteration")
plt.ylabel("True logL minus estimated logL")

ax = plt.gca()
xmin, xmax = ax.get_xlim()
ax.set_xticks(np.linspace(xmin, xmax, 5))
ax.set_xlim(xmin, xmax)

ax.set_yticks(np.linspace(*ax.get_ylim(), 4, dtype=int))

plt.tight_layout()
plt.savefig("results/simple/replicates_loglik_gap_simple.png", dpi=DPI)
